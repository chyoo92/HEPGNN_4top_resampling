# %%
import numpy as np
import uproot
import h5py
import os
import torch
import torch_geometric.nn as PyG
from torch_geometric.transforms import Distance
from torch_geometric.data import InMemoryDataset as PyGDataset, Data as PyGData
from torch_geometric.data import Data
import math
import numba
import numpy as np
import torch
import h5py
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as PyG
from torch_geometric.transforms import Distance
from torch_geometric.data import DataLoader
from torch_geometric.data import Data as PyGData
from torch_geometric.data import Data
import sys, os
import subprocess
import csv, yaml
import math
from tqdm import tqdm
from sklearn.metrics import accuracy_score
import torch.optim as optim
import argparse
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.tri as tri
# import numpy, numba, awkward, awkward.numba

# %%
# path = '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex2/220323_084833/delphes'
# graph_path = '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex2/220323_084833/graph/'
# output_path = '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex2/220323_084833/h5/'


path = '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes'
graph_path = '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/'
output_path = '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/h5/'

# %%
resampling_model = '/users/yewzzang/work/HEPGNN_4top_resampling/result/20220411_4top_run1'

# %%
sys.path.append("./python")

# %%
from model.allModel import *

model = torch.load(resampling_model+'/model.pth', map_location='cpu')
model.load_state_dict(torch.load(resampling_model+'/weight.pth', map_location='cpu'))
model = model.cuda()
device = 'cuda'

# %%
model
# Out:
# GCN3(
#   (conv1): GCNConv(4, 32)
#   (conv2): GCNConv(32, 64)
#   (conv3): GCNConv(64, 64)
#   (fc): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=32, out_features=1, bias=True)
#     (5): Softplus(beta=1, threshold=20)
#   )
# )

# %%
@numba.njit(nogil=True, fastmath=True, parallel=True)
def buildGraph(jetss_pt, jetss_eta, jetss_phi):
#     maxDR2 = 100
    maxDR2 = 0 ## maximum deltaR value to connect two jets
    graphs = []
    g = []
    
    selJets = (jetss_pt > 35) & (np.fabs(jetss_eta) < 2.4)

    jets_eta = jetss_eta[selJets]
    jets_phi = jetss_phi[selJets]
#     jets_eta = jetss_eta
#     jets_phi = jetss_phi
    
    nJet = len(jets_eta)
    prange = numba.prange
    for i in prange(nJet):
        for j in prange(i):
#     for i in range(nJet):
#         for j in range(i):
            dEta = jets_eta[i]-jets_eta[j]
            dPhi = jets_phi[i]-jets_phi[j]
            ## Move dPhi to [-pi,pi] range
            if   dPhi >= math.pi: dPhi -= 2*math.pi
            elif dPhi < -math.pi: dPhi += 2*math.pi
            ## Compute deltaR^2 and ask it is inside of our ball
            dR2 = dEta*dEta + dPhi*dPhi
            if dR2 > maxDR2: continue
            g.append([i,j])
            
    graphs.append(g)
    return graphs

# %%
def countNBjets(JetBTag):
    nEvent = int(len(JetBTag))
    NBjets = []
    for i in range(nEvent):
        selBjets = (JetBTag[i] > 0.5)
        numBjets = np.sum(selBjets)
        NBjets.append(numBjets)
    return np.array(NBjets, dtype=np.dtype('int64'))

# %%
res = []
for root, dirs, files in os.walk(path):
    rootpath = os.path.join(os.path.abspath(path), root)
    for file in files:
        filepath = os.path.join(rootpath, file)
        
        filetype = filepath.split('.')[-1]
        if filetype != 'root': continue
  
        res.append(filepath)

# %%
res
# Out:
# ['/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_93.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_2.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_6.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_28.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_41.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_91.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_5.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_85.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_74.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_12.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_37.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_9.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_26.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_54.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_15.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_46.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_89.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_71.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_31.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_4.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_79.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_92.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_32.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_86.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_62.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_21.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_66.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_72.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_51.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_75.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_24.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_98.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_17.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_80.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_8.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_56.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_48.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_83.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_82.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_61.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_23.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_36.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_68.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_34.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_16.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_60.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_14.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_67.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_70.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_81.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_18.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_50.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_58.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_20.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_52.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_3.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_77.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_43.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_65.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_40.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_13.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_45.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_47.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_10.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_19.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_73.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_57.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_11.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_63.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_97.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_29.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_87.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_44.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_94.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_76.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_88.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_90.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_64.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_95.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_59.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_84.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_96.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_27.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_22.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_49.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_42.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_25.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_69.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_33.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_7.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_30.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_53.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_1.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_39.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_38.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_55.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_78.root',
#  '/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/delphes/4top_ex1_delphes_35.root']

# %%
import time
preds = []
f_weight_list = []
start = time.time()
for i in range(len(res)):

    file_name = res[i]
    cla = file_name.split('/')[-4].split('_')
    num = file_name.split('/')[-1].split('.')[-2]

    

    save_f_name = num

    save_path = output_path
    if not os.path.exists(save_path): os.makedirs(save_path)
    save_file_name = save_path + save_f_name + '.pt'
#     print(save_file_name)
### load data
    try:
        r_data = uproot.open(file_name)["Delphes"] 
#     r_data = uproot.open(file_name)["Delphes"]
    except KeyError:
        print("delphes 없음")
        pass
    
    
    
    graph_file = graph_path + num.split('_')[0]+'_'+num.split('_')[1]+'_'+num.split('_')[3] + '.h5'
    
    
    
    f = h5py.File(graph_file,'r')
    nEvent = len(f['events']['m'])
    f_m = f['events']['m']
    f_px = f['events']['px']
    f_py = f['events']['py']
    f_pz = f['events']['pz']
    f_id = f['events']['id']
    f_weight = f['events']['weight']


    f_edge1 = f['graphs']['edge1']
    f_edge2 = f['graphs']['edge2']
    f_fea_list = []
    f_edge_list = []
    
    for j in range(nEvent):
        f_fea_reshape = torch.cat((torch.from_numpy(f_m[j]).reshape(-1,1),torch.from_numpy(f_px[j]).reshape(-1,1),torch.from_numpy(f_py[j]).reshape(-1,1),torch.from_numpy(f_pz[j]).reshape(-1,1)),1).float()   


        f_edge_reshape = torch.cat((torch.from_numpy(f_edge1[j]).reshape(1,-1),torch.from_numpy(f_edge2[j]).reshape(1,-1)),0).float()

        f_fea_list.append(f_fea_reshape)

        f_edge_list.append(f_edge_reshape)
        f_weight_list.append(f_weight[i])
    
    
    
    Muon_size = np.asarray(r_data["Muon_size"])
    Elec_size = np.asarray(r_data["Electron_size"])
    
    JetPt = np.asarray(r_data["Jet.PT"])
    JetEta = np.asarray(r_data["Jet.Eta"])
    JetPhi = np.asarray(r_data["Jet.Phi"])
    JetMass = np.asarray(r_data["Jet.Mass"])
    JetBTag = np.asarray(r_data["Jet.BTag"])
    
    FMass = np.asarray(r_data["FatJet.Mass"])
    FPt = np.asarray(r_data["FatJet.PT"])
    FEta = np.asarray(r_data["FatJet.Eta"])

    
    pos = []
    x_fea = []
    edge_t = []

    datalist = []
    model.eval()
    
    ## make data    
    for j in range(len(FPt)):
        
        ### selection
        

        numLepton = (Muon_size[j] + Elec_size[j])
        if numLepton > 0 : continue
            
        selJets = (JetPt[j] > 35) & (np.fabs(JetEta[j]) < 2.4)
        if np.sum(selJets) < 9: continue 
        ht = np.sum(JetPt[j][selJets])
        if  ht < 700: continue
        
        ##### make resampling weith
        
        feats = torch.Tensor(f_fea_list[j])
        edges = torch.Tensor(f_edge_list[j])
        edges = edges.type(dtype=torch.long)
        
 
        
        data = PyGData(x = feats, edge_index = edges, batch = torch.from_numpy(np.zeros([len(feats)],dtype = np.int)))

        data = data.to(device)
        pred = model(data)
        
        preds.append(torch.tensor(pred).cpu())
    print(graph_file,'finish')

print(time.time()-start)
# Out:
# /users/yewzzang/.local/lib/python3.7/site-packages/ipykernel_launcher.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_93.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_2.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_6.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_28.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_41.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_91.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_5.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_85.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_74.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_12.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_37.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_9.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_26.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_54.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_15.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_46.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_89.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_71.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_31.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_4.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_79.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_92.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_32.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_86.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_62.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_21.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_66.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_72.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_51.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_75.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_24.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_98.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_17.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_80.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_8.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_56.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_48.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_83.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_82.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_61.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_23.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_36.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_68.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_34.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_16.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_60.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_14.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_67.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_70.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_81.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_18.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_50.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_58.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_20.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_52.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_3.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_77.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_43.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_65.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_40.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_13.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_45.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_47.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_10.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_19.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_73.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_57.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_11.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_63.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_97.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_29.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_87.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_44.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_94.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_76.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_88.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_90.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_64.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_95.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_59.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_84.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_96.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_27.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_22.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_49.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_42.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_25.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_69.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_33.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_7.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_30.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_53.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_1.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_39.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_38.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_55.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_78.h5 finish
# /users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex1/220324_055935/graph/4top_ex1_35.h5 finish
# 3527.9489612579346

# %%
import matplotlib.pyplot as plt

# %%
torch.tensor(pred).cpu()
# Out:
# /users/yewzzang/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """Entry point for launching an IPython kernel.
# tensor([[0.6442]])

# %%
preds
# Out:
# [tensor([[0.6247]]),
#  tensor([[0.6262]]),
#  tensor([[0.6494]]),
#  tensor([[0.6309]]),
#  tensor([[0.0030]]),
#  tensor([[0.6254]]),
#  tensor([[0.6276]]),
#  tensor([[0.6338]]),
#  tensor([[0.6311]]),
#  tensor([[0.0024]]),
#  tensor([[0.6318]]),
#  tensor([[0.6305]]),
#  tensor([[0.6300]]),
#  tensor([[0.6357]]),
#  tensor([[0.6219]]),
#  tensor([[0.6227]]),
#  tensor([[0.6320]]),
#  tensor([[0.6313]]),
#  tensor([[0.6299]]),
#  tensor([[0.0050]]),
#  tensor([[0.0019]]),
#  tensor([[0.6290]]),
#  tensor([[0.0093]]),
#  tensor([[0.6305]]),
#  tensor([[0.6237]]),
#  tensor([[0.6288]]),
#  tensor([[0.0111]]),
#  tensor([[0.6194]]),
#  tensor([[0.6355]]),
#  tensor([[0.0050]]),
#  tensor([[0.6164]]),
#  tensor([[0.6306]]),
#  tensor([[0.6283]]),
#  tensor([[0.6292]]),
#  tensor([[0.0039]]),
#  tensor([[0.6233]]),
#  tensor([[0.6270]]),
#  tensor([[0.0023]]),
#  tensor([[0.6269]]),
#  tensor([[0.6315]]),
#  tensor([[0.6279]]),
#  tensor([[0.6375]]),
#  tensor([[0.6241]]),
#  tensor([[0.6283]]),
#  tensor([[0.6322]]),
#  tensor([[0.6292]]),
#  tensor([[0.6147]]),
#  tensor([[0.6255]]),
#  tensor([[0.6348]]),
#  tensor([[0.6277]]),
#  tensor([[0.6263]]),
#  tensor([[0.6114]]),
#  tensor([[0.6347]]),
#  tensor([[0.0035]]),
#  tensor([[0.6265]]),
#  tensor([[0.0024]]),
#  tensor([[0.6256]]),
#  tensor([[0.6321]]),
#  tensor([[0.6185]]),
#  tensor([[0.6296]]),
#  tensor([[0.6282]]),
#  tensor([[0.0043]]),
#  tensor([[0.6323]]),
#  tensor([[0.0024]]),
#  tensor([[0.0022]]),
#  tensor([[0.6330]]),
#  tensor([[0.6333]]),
#  tensor([[0.6238]]),
#  tensor([[0.6294]]),
#  tensor([[0.6371]]),
#  tensor([[0.6333]]),
#  tensor([[0.0023]]),
#  tensor([[0.6299]]),
#  tensor([[0.6484]]),
#  tensor([[0.6299]]),
#  tensor([[0.6283]]),
#  tensor([[0.6104]]),
#  tensor([[0.6299]]),
#  tensor([[0.6256]]),
#  tensor([[0.6259]]),
#  tensor([[0.0026]]),
#  tensor([[0.6398]]),
#  tensor([[0.6245]]),
#  tensor([[0.6321]]),
#  tensor([[0.6346]]),
#  tensor([[0.6118]]),
#  tensor([[0.6234]]),
#  tensor([[0.6381]]),
#  tensor([[0.0022]]),
#  tensor([[0.0032]]),
#  tensor([[0.6234]]),
#  tensor([[0.0027]]),
#  tensor([[0.0030]]),
#  tensor([[0.6290]]),
#  tensor([[0.6294]]),
#  tensor([[0.0022]]),
#  tensor([[0.0034]]),
#  tensor([[0.6189]]),
#  tensor([[0.0024]]),
#  tensor([[0.0019]]),
#  tensor([[0.6311]]),
#  tensor([[0.0021]]),
#  tensor([[0.0073]]),
#  tensor([[0.0001]]),
#  tensor([[0.6265]]),
#  tensor([[0.6383]]),
#  tensor([[0.0026]]),
#  tensor([[0.6339]]),
#  tensor([[0.6327]]),
#  tensor([[0.6233]]),
#  tensor([[0.0007]]),
#  tensor([[0.0025]]),
#  tensor([[0.6345]]),
#  tensor([[0.6338]]),
#  tensor([[0.6224]]),
#  tensor([[0.6432]]),
#  tensor([[0.0035]]),
#  tensor([[0.6335]]),
#  tensor([[0.0031]]),
#  tensor([[0.6320]]),
#  tensor([[0.6370]]),
#  tensor([[0.0175]]),
#  tensor([[0.6292]]),
#  tensor([[0.0034]]),
#  tensor([[0.6388]]),
#  tensor([[0.6319]]),
#  tensor([[0.6319]]),
#  tensor([[0.6286]]),
#  tensor([[0.6265]]),
#  tensor([[0.6294]]),
#  tensor([[0.6238]]),
#  tensor([[0.6276]]),
#  tensor([[0.0023]]),
#  tensor([[0.0002]]),
#  tensor([[0.6412]]),
#  tensor([[0.6259]]),
#  tensor([[0.6174]]),
#  tensor([[0.6327]]),
#  tensor([[0.0017]]),
#  tensor([[0.6334]]),
#  tensor([[0.0019]]),
#  tensor([[0.0023]]),
#  tensor([[0.0029]]),
#  tensor([[0.6233]]),
#  tensor([[0.6030]]),
#  tensor([[0.6368]]),
#  tensor([[0.6205]]),
#  tensor([[0.6278]]),
#  tensor([[0.0012]]),
#  tensor([[0.6341]]),
#  tensor([[0.6322]]),
#  tensor([[0.6259]]),
#  tensor([[0.0040]]),
#  tensor([[0.6285]]),
#  tensor([[0.6279]]),
#  tensor([[0.6361]]),
#  tensor([[0.0013]]),
#  tensor([[0.0081]]),
#  tensor([[0.6360]]),
#  tensor([[0.6322]]),
#  tensor([[0.0034]]),
#  tensor([[0.6331]]),
#  tensor([[0.6487]]),
#  tensor([[0.0033]]),
#  tensor([[0.6384]]),
#  tensor([[0.0023]]),
#  tensor([[0.6318]]),
#  tensor([[0.6331]]),
#  tensor([[0.6380]]),
#  tensor([[0.0012]]),
#  tensor([[0.0029]]),
#  tensor([[0.0019]]),
#  tensor([[0.6280]]),
#  tensor([[0.6318]]),
#  tensor([[0.6275]]),
#  tensor([[0.6257]]),
#  tensor([[0.6288]]),
#  tensor([[0.6360]]),
#  tensor([[0.6245]]),
#  tensor([[0.6237]]),
#  tensor([[0.6248]]),
#  tensor([[0.0021]]),
#  tensor([[0.6230]]),
#  tensor([[0.6294]]),
#  tensor([[0.6247]]),
#  tensor([[0.6199]]),
#  tensor([[0.6260]]),
#  tensor([[0.0037]]),
#  tensor([[0.6331]]),
#  tensor([[0.6255]]),
#  tensor([[0.6214]]),
#  tensor([[0.6418]]),
#  tensor([[0.0007]]),
#  tensor([[0.6213]]),
#  tensor([[0.0016]]),
#  tensor([[0.6289]]),
#  tensor([[0.0018]]),
#  tensor([[0.6331]]),
#  tensor([[0.0061]]),
#  tensor([[0.6295]]),
#  tensor([[0.0046]]),
#  tensor([[0.0027]]),
#  tensor([[0.6227]]),
#  tensor([[0.0014]]),
#  tensor([[0.6076]]),
#  tensor([[0.6303]]),
#  tensor([[0.0002]]),
#  tensor([[0.6264]]),
#  tensor([[0.6315]]),
#  tensor([[0.6309]]),
#  tensor([[0.6320]]),
#  tensor([[0.0003]]),
#  tensor([[0.6272]]),
#  tensor([[0.0027]]),
#  tensor([[0.6187]]),
#  tensor([[0.6216]]),
#  tensor([[0.0054]]),
#  tensor([[0.6275]]),
#  tensor([[0.6244]]),
#  tensor([[0.0037]]),
#  tensor([[0.6310]]),
#  tensor([[0.6369]]),
#  tensor([[0.0021]]),
#  tensor([[0.0023]]),
#  tensor([[0.6296]]),
#  tensor([[0.0015]]),
#  tensor([[0.6395]]),
#  tensor([[0.6232]]),
#  tensor([[0.6247]]),
#  tensor([[0.6471]]),
#  tensor([[0.6255]]),
#  tensor([[0.0012]]),
#  tensor([[0.6213]]),
#  tensor([[0.6258]]),
#  tensor([[0.6284]]),
#  tensor([[0.6219]]),
#  tensor([[0.6276]]),
#  tensor([[0.6186]]),
#  tensor([[0.6278]]),
#  tensor([[0.0034]]),
#  tensor([[0.6299]]),
#  tensor([[0.6361]]),
#  tensor([[0.6311]]),
#  tensor([[0.0009]]),
#  tensor([[0.6274]]),
#  tensor([[0.6204]]),
#  tensor([[0.6313]]),
#  tensor([[0.6275]]),
#  tensor([[0.0034]]),
#  tensor([[0.0024]]),
#  tensor([[0.0037]]),
#  tensor([[0.6303]]),
#  tensor([[0.6255]]),
#  tensor([[0.6302]]),
#  tensor([[0.6294]]),
#  tensor([[0.0015]]),
#  tensor([[0.6331]]),
#  tensor([[0.0017]]),
#  tensor([[0.0311]]),
#  tensor([[0.6246]]),
#  tensor([[0.6280]]),
#  tensor([[0.0014]]),
#  tensor([[0.0009]]),
#  tensor([[0.0016]]),
#  tensor([[0.6246]]),
#  tensor([[0.6292]]),
#  tensor([[0.6277]]),
#  tensor([[0.6275]]),
#  tensor([[0.6270]]),
#  tensor([[0.6384]]),
#  tensor([[0.6384]]),
#  tensor([[0.6390]]),
#  tensor([[0.6172]]),
#  tensor([[0.6293]]),
#  tensor([[0.6264]]),
#  tensor([[0.0012]]),
#  tensor([[0.0033]]),
#  tensor([[0.6465]]),
#  tensor([[0.6257]]),
#  tensor([[0.0028]]),
#  tensor([[0.0035]]),
#  tensor([[0.6318]]),
#  tensor([[0.6364]]),
#  tensor([[0.6378]]),
#  tensor([[0.6267]]),
#  tensor([[0.6327]]),
#  tensor([[0.6272]]),
#  tensor([[0.6305]]),
#  tensor([[0.6095]]),
#  tensor([[0.6296]]),
#  tensor([[0.6282]]),
#  tensor([[0.6374]]),
#  tensor([[0.6193]]),
#  tensor([[0.6304]]),
#  tensor([[0.6281]]),
#  tensor([[0.6347]]),
#  tensor([[0.0012]]),
#  tensor([[0.6265]]),
#  tensor([[0.6296]]),
#  tensor([[0.0032]]),
#  tensor([[0.6281]]),
#  tensor([[0.0022]]),
#  tensor([[0.6364]]),
#  tensor([[0.6320]]),
#  tensor([[0.0035]]),
#  tensor([[0.6269]]),
#  tensor([[0.6329]]),
#  tensor([[0.0014]]),
#  tensor([[0.6223]]),
#  tensor([[0.6304]]),
#  tensor([[0.6319]]),
#  tensor([[0.6319]]),
#  tensor([[0.0024]]),
#  tensor([[0.6327]]),
#  tensor([[0.6329]]),
#  tensor([[0.6308]]),
#  tensor([[0.6347]]),
#  tensor([[0.6344]]),
#  tensor([[0.6269]]),
#  tensor([[0.6315]]),
#  tensor([[0.6233]]),
#  tensor([[0.6392]]),
#  tensor([[0.6278]]),
#  tensor([[0.6298]]),
#  tensor([[0.6280]]),
#  tensor([[0.0019]]),
#  tensor([[0.6315]]),
#  tensor([[0.6235]]),
#  tensor([[0.6260]]),
#  tensor([[0.6283]]),
#  tensor([[5.5617e-05]]),
#  tensor([[0.6238]]),
#  tensor([[0.6402]]),
#  tensor([[0.6362]]),
#  tensor([[0.0025]]),
#  tensor([[0.0030]]),
#  tensor([[0.6283]]),
#  tensor([[0.0022]]),
#  tensor([[0.0033]]),
#  tensor([[0.6175]]),
#  tensor([[0.6258]]),
#  tensor([[0.0036]]),
#  tensor([[0.6172]]),
#  tensor([[0.6115]]),
#  tensor([[0.0048]]),
#  tensor([[0.6304]]),
#  tensor([[0.0034]]),
#  tensor([[0.6263]]),
#  tensor([[0.6250]]),
#  tensor([[0.0012]]),
#  tensor([[0.0014]]),
#  tensor([[0.0023]]),
#  tensor([[0.6286]]),
#  tensor([[0.6284]]),
#  tensor([[0.6252]]),
#  tensor([[0.6294]]),
#  tensor([[0.0035]]),
#  tensor([[0.6283]]),
#  tensor([[0.6273]]),
#  tensor([[0.6336]]),
#  tensor([[0.6368]]),
#  tensor([[0.6301]]),
#  tensor([[0.6320]]),
#  tensor([[0.6301]]),
#  tensor([[0.6321]]),
#  tensor([[0.4391]]),
#  tensor([[0.6302]]),
#  tensor([[0.6138]]),
#  tensor([[0.0019]]),
#  tensor([[0.6292]]),
#  tensor([[0.6341]]),
#  tensor([[0.6274]]),
#  tensor([[0.0034]]),
#  tensor([[0.0050]]),
#  tensor([[0.6356]]),
#  tensor([[0.0022]]),
#  tensor([[0.6302]]),
#  tensor([[0.6293]]),
#  tensor([[0.6326]]),
#  tensor([[0.6362]]),
#  tensor([[0.6296]]),
#  tensor([[0.0015]]),
#  tensor([[0.6223]]),
#  tensor([[0.0019]]),
#  tensor([[0.6377]]),
#  tensor([[0.6337]]),
#  tensor([[0.0020]]),
#  tensor([[0.6298]]),
#  tensor([[0.6287]]),
#  tensor([[0.6457]]),
#  tensor([[0.0038]]),
#  tensor([[0.6234]]),
#  tensor([[0.6311]]),
#  tensor([[0.6247]]),
#  tensor([[0.6332]]),
#  tensor([[0.0037]]),
#  tensor([[0.0016]]),
#  tensor([[0.6417]]),
#  tensor([[0.0046]]),
#  tensor([[0.0041]]),
#  tensor([[0.6260]]),
#  tensor([[0.6318]]),
#  tensor([[0.6217]]),
#  tensor([[0.6184]]),
#  tensor([[0.6346]]),
#  tensor([[0.6275]]),
#  tensor([[0.6305]]),
#  tensor([[0.6247]]),
#  tensor([[0.6333]]),
#  tensor([[0.6293]]),
#  tensor([[0.6432]]),
#  tensor([[0.6313]]),
#  tensor([[0.6299]]),
#  tensor([[0.6384]]),
#  tensor([[0.6327]]),
#  tensor([[0.6233]]),
#  tensor([[0.0066]]),
#  tensor([[0.6303]]),
#  tensor([[0.6306]]),
#  tensor([[0.6251]]),
#  tensor([[0.6311]]),
#  tensor([[0.0019]]),
#  tensor([[0.6187]]),
#  tensor([[0.6250]]),
#  tensor([[0.6264]]),
#  tensor([[0.0042]]),
#  tensor([[0.6310]]),
#  tensor([[0.6345]]),
#  tensor([[0.6262]]),
#  tensor([[0.6304]]),
#  tensor([[0.6241]]),
#  tensor([[0.6383]]),
#  tensor([[0.6310]]),
#  tensor([[0.0021]]),
#  tensor([[0.6328]]),
#  tensor([[0.6280]]),
#  tensor([[0.6202]]),
#  tensor([[0.6260]]),
#  tensor([[0.6310]]),
#  tensor([[0.6216]]),
#  tensor([[0.6340]]),
#  tensor([[0.6281]]),
#  tensor([[0.6351]]),
#  tensor([[0.6248]]),
#  tensor([[0.6382]]),
#  tensor([[0.6342]]),
#  tensor([[0.6292]]),
#  tensor([[0.6117]]),
#  tensor([[0.6332]]),
#  tensor([[0.6296]]),
#  tensor([[0.6270]]),
#  tensor([[0.6298]]),
#  tensor([[0.6354]]),
#  tensor([[0.0081]]),
#  tensor([[0.0040]]),
#  tensor([[0.6200]]),
#  tensor([[0.6278]]),
#  tensor([[0.6365]]),
#  tensor([[0.6290]]),
#  tensor([[0.0019]]),
#  tensor([[0.6284]]),
#  tensor([[0.6196]]),
#  tensor([[0.6260]]),
#  tensor([[0.6180]]),
#  tensor([[0.0038]]),
#  tensor([[0.0026]]),
#  tensor([[0.0025]]),
#  tensor([[0.6272]]),
#  tensor([[0.6313]]),
#  tensor([[0.6242]]),
#  tensor([[0.6308]]),
#  tensor([[0.6274]]),
#  tensor([[0.6211]]),
#  tensor([[0.6383]]),
#  tensor([[0.6222]]),
#  tensor([[0.6164]]),
#  tensor([[0.6363]]),
#  tensor([[0.6267]]),
#  tensor([[0.6239]]),
#  tensor([[0.0069]]),
#  tensor([[0.6266]]),
#  tensor([[0.0026]]),
#  tensor([[0.6224]]),
#  tensor([[0.6251]]),
#  tensor([[0.6279]]),
#  tensor([[0.6298]]),
#  tensor([[0.6291]]),
#  tensor([[0.0022]]),
#  tensor([[0.6242]]),
#  tensor([[0.6217]]),
#  tensor([[0.6329]]),
#  tensor([[0.0062]]),
#  tensor([[0.0008]]),
#  tensor([[0.0016]]),
#  tensor([[0.0030]]),
#  tensor([[0.0015]]),
#  tensor([[0.6398]]),
#  tensor([[0.0038]]),
#  tensor([[0.6287]]),
#  tensor([[0.6332]]),
#  tensor([[0.6293]]),
#  tensor([[0.6331]]),
#  tensor([[0.6250]]),
#  tensor([[0.6297]]),
#  tensor([[0.0014]]),
#  tensor([[0.0023]]),
#  tensor([[0.6206]]),
#  tensor([[0.0046]]),
#  tensor([[0.6263]]),
#  tensor([[0.6255]]),
#  tensor([[0.0022]]),
#  tensor([[0.6259]]),
#  tensor([[0.6342]]),
#  tensor([[0.0003]]),
#  tensor([[0.6298]]),
#  tensor([[0.6315]]),
#  tensor([[0.6318]]),
#  tensor([[0.0017]]),
#  tensor([[0.0030]]),
#  tensor([[0.6279]]),
#  tensor([[0.0079]]),
#  tensor([[0.6273]]),
#  tensor([[0.0019]]),
#  tensor([[0.6338]]),
#  tensor([[0.6315]]),
#  tensor([[0.6242]]),
#  tensor([[0.6301]]),
#  tensor([[0.6467]]),
#  tensor([[0.6266]]),
#  tensor([[0.6355]]),
#  tensor([[0.0012]]),
#  tensor([[0.6324]]),
#  tensor([[0.0032]]),
#  tensor([[0.6235]]),
#  tensor([[0.6306]]),
#  tensor([[0.6292]]),
#  tensor([[0.6251]]),
#  tensor([[0.0015]]),
#  tensor([[0.6210]]),
#  tensor([[0.6287]]),
#  tensor([[0.6281]]),
#  tensor([[0.0025]]),
#  tensor([[0.6303]]),
#  tensor([[0.6295]]),
#  tensor([[0.6321]]),
#  tensor([[0.0013]]),
#  tensor([[0.0058]]),
#  tensor([[0.0172]]),
#  tensor([[0.6290]]),
#  tensor([[0.6241]]),
#  tensor([[0.0097]]),
#  tensor([[0.6347]]),
#  tensor([[0.6430]]),
#  tensor([[0.6404]]),
#  tensor([[0.6240]]),
#  tensor([[0.6273]]),
#  tensor([[0.6360]]),
#  tensor([[0.6276]]),
#  tensor([[0.6280]]),
#  tensor([[0.0027]]),
#  tensor([[0.6364]]),
#  tensor([[0.6306]]),
#  tensor([[0.6292]]),
#  tensor([[0.6413]]),
#  tensor([[0.0005]]),
#  tensor([[0.6305]]),
#  tensor([[0.6252]]),
#  tensor([[0.0024]]),
#  tensor([[0.6224]]),
#  tensor([[0.0023]]),
#  tensor([[0.6314]]),
#  tensor([[0.6448]]),
#  tensor([[0.6275]]),
#  tensor([[0.0041]]),
#  tensor([[0.0011]]),
#  tensor([[0.6191]]),
#  tensor([[0.6281]]),
#  tensor([[0.6277]]),
#  tensor([[0.6283]]),
#  tensor([[0.6236]]),
#  tensor([[0.6210]]),
#  tensor([[0.6336]]),
#  tensor([[0.6281]]),
#  tensor([[0.6275]]),
#  tensor([[0.6309]]),
#  tensor([[0.6332]]),
#  tensor([[0.6289]]),
#  tensor([[0.6274]]),
#  tensor([[0.0025]]),
#  tensor([[0.6285]]),
#  tensor([[0.6242]]),
#  tensor([[0.6280]]),
#  tensor([[0.6263]]),
#  tensor([[0.6223]]),
#  tensor([[0.0022]]),
#  tensor([[0.6326]]),
#  tensor([[0.6305]]),
#  tensor([[0.6178]]),
#  tensor([[0.6295]]),
#  tensor([[0.6305]]),
#  tensor([[0.6229]]),
#  tensor([[0.6295]]),
#  tensor([[0.6285]]),
#  tensor([[0.6300]]),
#  tensor([[0.6255]]),
#  tensor([[0.6249]]),
#  tensor([[0.0027]]),
#  tensor([[0.6309]]),
#  tensor([[0.6267]]),
#  tensor([[0.6186]]),
#  tensor([[0.6285]]),
#  tensor([[0.6263]]),
#  tensor([[0.6293]]),
#  tensor([[0.6375]]),
#  tensor([[0.6354]]),
#  tensor([[0.6239]]),
#  tensor([[0.6333]]),
#  tensor([[0.6291]]),
#  tensor([[0.6315]]),
#  tensor([[0.6272]]),
#  tensor([[0.6289]]),
#  tensor([[0.6252]]),
#  tensor([[0.0022]]),
#  tensor([[0.6328]]),
#  tensor([[0.0021]]),
#  tensor([[0.6428]]),
#  tensor([[0.6225]]),
#  tensor([[0.6308]]),
#  tensor([[0.6244]]),
#  tensor([[0.0027]]),
#  tensor([[0.6286]]),
#  tensor([[0.0012]]),
#  tensor([[0.0018]]),
#  tensor([[0.6202]]),
#  tensor([[0.6275]]),
#  tensor([[0.0015]]),
#  tensor([[0.6260]]),
#  tensor([[0.6265]]),
#  tensor([[0.6234]]),
#  tensor([[0.0027]]),
#  tensor([[0.6282]]),
#  tensor([[0.6227]]),
#  tensor([[0.6343]]),
#  tensor([[0.6267]]),
#  tensor([[0.6327]]),
#  tensor([[0.6254]]),
#  tensor([[0.6332]]),
#  tensor([[0.6293]]),
#  tensor([[0.0026]]),
#  tensor([[0.6326]]),
#  tensor([[0.0029]]),
#  tensor([[0.6359]]),
#  tensor([[0.6365]]),
#  tensor([[0.6249]]),
#  tensor([[0.6300]]),
#  tensor([[0.0014]]),
#  tensor([[0.0032]]),
#  tensor([[0.0023]]),
#  tensor([[0.0009]]),
#  tensor([[0.0042]]),
#  tensor([[0.6255]]),
#  tensor([[0.6317]]),
#  tensor([[0.6244]]),
#  tensor([[0.6374]]),
#  tensor([[0.0034]]),
#  tensor([[0.0026]]),
#  tensor([[0.0034]]),
#  tensor([[0.6339]]),
#  tensor([[0.6260]]),
#  tensor([[0.6321]]),
#  tensor([[0.6208]]),
#  tensor([[0.6229]]),
#  tensor([[0.6243]]),
#  tensor([[0.6290]]),
#  tensor([[0.6218]]),
#  tensor([[0.6266]]),
#  tensor([[0.6260]]),
#  tensor([[0.6309]]),
#  tensor([[0.6405]]),
#  tensor([[0.6304]]),
#  tensor([[0.6338]]),
#  tensor([[0.6237]]),
#  tensor([[0.6292]]),
#  tensor([[0.0025]]),
#  tensor([[0.0021]]),
#  tensor([[0.6310]]),
#  tensor([[0.6360]]),
#  tensor([[0.6276]]),
#  tensor([[0.6304]]),
#  tensor([[0.0031]]),
#  tensor([[0.0084]]),
#  tensor([[0.6276]]),
#  tensor([[0.0027]]),
#  tensor([[0.0033]]),
#  tensor([[0.0011]]),
#  tensor([[0.0020]]),
#  tensor([[0.6329]]),
#  tensor([[0.6330]]),
#  tensor([[0.6294]]),
#  tensor([[0.6266]]),
#  tensor([[0.6207]]),
#  tensor([[0.6250]]),
#  tensor([[0.6123]]),
#  tensor([[0.6211]]),
#  tensor([[0.6279]]),
#  tensor([[0.6292]]),
#  tensor([[0.0007]]),
#  tensor([[0.6316]]),
#  tensor([[0.6380]]),
#  tensor([[0.0010]]),
#  tensor([[0.5881]]),
#  tensor([[0.6461]]),
#  tensor([[0.6247]]),
#  tensor([[0.6357]]),
#  tensor([[0.6337]]),
#  tensor([[0.0021]]),
#  tensor([[0.6285]]),
#  tensor([[0.0181]]),
#  tensor([[0.0028]]),
#  tensor([[0.6317]]),
#  tensor([[0.6228]]),
#  tensor([[0.0018]]),
#  tensor([[0.0024]]),
#  tensor([[0.6270]]),
#  tensor([[0.6487]]),
#  tensor([[0.6295]]),
#  tensor([[0.0006]]),
#  tensor([[0.6315]]),
#  tensor([[0.6303]]),
#  tensor([[0.6304]]),
#  tensor([[0.0018]]),
#  tensor([[0.6279]]),
#  tensor([[0.6242]]),
#  tensor([[0.0059]]),
#  tensor([[0.6284]]),
#  tensor([[0.6257]]),
#  tensor([[0.6307]]),
#  tensor([[0.6290]]),
#  tensor([[0.6288]]),
#  tensor([[0.6238]]),
#  tensor([[0.0013]]),
#  tensor([[0.0011]]),
#  tensor([[0.6244]]),
#  tensor([[0.6386]]),
#  tensor([[0.6388]]),
#  tensor([[0.0026]]),
#  tensor([[0.6285]]),
#  tensor([[0.0041]]),
#  tensor([[0.6283]]),
#  tensor([[0.6334]]),
#  tensor([[0.6278]]),
#  tensor([[0.6265]]),
#  tensor([[0.0020]]),
#  tensor([[0.6252]]),
#  tensor([[0.0021]]),
#  tensor([[0.0024]]),
#  tensor([[0.6265]]),
#  tensor([[0.6297]]),
#  tensor([[0.6296]]),
#  tensor([[0.6273]]),
#  tensor([[0.6159]]),
#  tensor([[0.0046]]),
#  tensor([[0.0018]]),
#  tensor([[0.6381]]),
#  tensor([[0.6261]]),
#  tensor([[0.6248]]),
#  tensor([[0.6309]]),
#  tensor([[0.0023]]),
#  tensor([[0.6268]]),
#  tensor([[0.6369]]),
#  tensor([[0.6262]]),
#  tensor([[0.6291]]),
#  tensor([[0.6246]]),
#  tensor([[0.6283]]),
#  tensor([[0.6402]]),
#  tensor([[0.0030]]),
#  tensor([[0.6284]]),
#  tensor([[0.0041]]),
#  tensor([[0.6311]]),
#  tensor([[0.0040]]),
#  tensor([[0.6315]]),
#  tensor([[0.6348]]),
#  tensor([[0.6261]]),
#  tensor([[0.6337]]),
#  tensor([[0.6302]]),
#  tensor([[0.6341]]),
#  tensor([[0.0024]]),
#  tensor([[0.6139]]),
#  tensor([[0.6299]]),
#  tensor([[0.6193]]),
#  tensor([[0.6306]]),
#  tensor([[0.0036]]),
#  tensor([[0.6247]]),
#  tensor([[0.6353]]),
#  tensor([[0.6303]]),
#  tensor([[0.6247]]),
#  tensor([[0.6260]]),
#  tensor([[0.6312]]),
#  tensor([[0.0031]]),
#  tensor([[0.6299]]),
#  tensor([[0.6280]]),
#  tensor([[0.6340]]),
#  tensor([[0.6261]]),
#  tensor([[0.6246]]),
#  tensor([[0.6339]]),
#  tensor([[0.6284]]),
#  tensor([[0.6320]]),
#  tensor([[0.6296]]),
#  tensor([[0.6188]]),
#  tensor([[0.6334]]),
#  tensor([[0.6323]]),
#  tensor([[0.6192]]),
#  tensor([[0.6336]]),
#  tensor([[0.6365]]),
#  tensor([[0.6310]]),
#  tensor([[0.0025]]),
#  tensor([[0.0070]]),
#  tensor([[0.6157]]),
#  tensor([[0.6195]]),
#  tensor([[0.6117]]),
#  tensor([[0.6068]]),
#  tensor([[0.6294]]),
#  tensor([[0.0025]]),
#  tensor([[0.6322]]),
#  tensor([[0.6255]]),
#  tensor([[0.6322]]),
#  tensor([[0.6307]]),
#  tensor([[0.6281]]),
#  tensor([[0.0024]]),
#  tensor([[0.0113]]),
#  tensor([[0.0002]]),
#  tensor([[0.6279]]),
#  tensor([[9.8478e-05]]),
#  tensor([[0.6292]]),
#  tensor([[0.0019]]),
#  tensor([[0.6266]]),
#  tensor([[0.6332]]),
#  tensor([[0.0023]]),
#  tensor([[0.6282]]),
#  tensor([[0.6231]]),
#  tensor([[0.6305]]),
#  tensor([[0.0022]]),
#  tensor([[0.6319]]),
#  tensor([[0.0033]]),
#  tensor([[0.0046]]),
#  tensor([[0.6279]]),
#  tensor([[0.6381]]),
#  tensor([[0.6297]]),
#  tensor([[0.6214]]),
#  tensor([[0.6288]]),
#  tensor([[0.6336]]),
#  tensor([[0.0025]]),
#  tensor([[0.0018]]),
#  tensor([[0.6355]]),
#  tensor([[0.0009]]),
#  tensor([[0.0027]]),
#  tensor([[0.6192]]),
#  tensor([[0.0017]]),
#  tensor([[0.6199]]),
#  tensor([[0.6345]]),
#  tensor([[0.6303]]),
#  tensor([[0.6184]]),
#  tensor([[0.0067]]),
#  tensor([[0.0004]]),
#  tensor([[0.6352]]),
#  tensor([[0.0035]]),
#  tensor([[0.6289]]),
#  tensor([[0.6266]]),
#  tensor([[0.0035]]),
#  tensor([[0.6295]]),
#  tensor([[0.6387]]),
#  tensor([[0.6290]]),
#  tensor([[0.6243]]),
#  tensor([[0.6264]]),
#  tensor([[0.6302]]),
#  tensor([[0.0030]]),
#  tensor([[0.6234]]),
#  tensor([[0.6245]]),
#  tensor([[0.0020]]),
#  tensor([[0.0067]]),
#  tensor([[0.0019]]),
#  tensor([[0.6341]]),
#  tensor([[0.6338]]),
#  tensor([[0.0023]]),
#  tensor([[0.0051]]),
#  tensor([[0.6246]]),
#  tensor([[0.6318]]),
#  tensor([[0.6193]]),
#  tensor([[0.0044]]),
#  tensor([[0.6316]]),
#  tensor([[0.6183]]),
#  tensor([[0.6268]]),
#  tensor([[0.6262]]),
#  tensor([[0.6325]]),
#  tensor([[0.6404]]),
#  tensor([[0.6326]]),
#  tensor([[0.6313]]),
#  tensor([[0.6303]]),
#  tensor([[0.6260]]),
#  tensor([[0.6315]]),
#  tensor([[0.0026]]),
#  tensor([[0.6235]]),
#  tensor([[0.6338]]),
#  tensor([[0.6271]]),
#  tensor([[0.0019]]),
#  tensor([[0.6236]]),
#  tensor([[0.0038]]),
#  tensor([[0.0016]]),
#  tensor([[0.6215]]),
#  tensor([[0.6366]]),
#  tensor([[0.0025]]),
#  tensor([[0.6316]]),
#  tensor([[0.6336]]),
#  tensor([[0.6315]]),
#  tensor([[0.6276]]),
#  tensor([[0.0023]]),
#  tensor([[0.6328]]),
#  tensor([[0.6284]]),
#  tensor([[0.6319]]),
#  tensor([[0.6316]]),
#  tensor([[0.6103]]),
#  tensor([[0.6280]]),
#  tensor([[0.6248]]),
#  tensor([[0.0021]]),
#  tensor([[0.6314]]),
#  tensor([[0.6283]]),
#  tensor([[0.6336]]),
#  tensor([[0.6201]]),
#  tensor([[0.0012]]),
#  tensor([[0.0041]]),
#  tensor([[0.0130]]),
#  tensor([[0.6299]]),
#  tensor([[0.0021]]),
#  tensor([[0.6268]]),
#  tensor([[0.6287]]),
#  tensor([[0.6266]]),
#  tensor([[0.6257]]),
#  tensor([[0.6254]]),
#  tensor([[0.6245]]),
#  tensor([[0.6207]]),
#  tensor([[0.6090]]),
#  tensor([[0.6315]]),
#  tensor([[0.0017]]),
#  tensor([[0.6294]]),
#  tensor([[0.6310]]),
#  tensor([[0.0022]]),
#  tensor([[0.6337]]),
#  tensor([[0.0080]]),
#  tensor([[0.6293]]),
#  tensor([[0.6247]]),
#  tensor([[0.6324]]),
#  tensor([[0.6341]]),
#  tensor([[0.6238]]),
#  tensor([[0.6355]]),
#  tensor([[0.0043]]),
#  tensor([[0.6290]]),
#  tensor([[0.6289]]),
#  tensor([[0.2143]]),
#  tensor([[0.6250]]),
#  tensor([[0.0083]]),
#  tensor([[0.6296]]),
#  tensor([[0.6356]]),
#  tensor([[0.0020]]),
#  tensor([[0.6322]]),
#  tensor([[0.0004]]),
#  tensor([[0.6323]]),
#  tensor([[0.6179]]),
#  tensor([[0.0025]]),
#  tensor([[0.6316]]),
#  tensor([[0.6311]]),
#  tensor([[0.6250]]),
#  tensor([[0.6361]]),
#  tensor([[0.6245]]),
#  tensor([[0.6203]]),
#  tensor([[0.0043]]),
#  tensor([[0.0011]]),
#  tensor([[0.0025]]),
#  tensor([[0.0041]]),
#  tensor([[0.6290]]),
#  tensor([[0.6318]]),
#  tensor([[0.6319]]),
#  tensor([[0.6428]]),
#  tensor([[0.6308]]),
#  tensor([[0.6302]]),
#  tensor([[0.6264]]),
#  tensor([[0.6220]]),
#  tensor([[0.6288]]),
#  tensor([[0.6238]]),
#  tensor([[0.6268]]),
#  tensor([[0.6214]]),
#  tensor([[0.6347]]),
#  tensor([[0.6312]]),
#  tensor([[0.6298]]),
#  tensor([[0.6307]]),
#  tensor([[0.6296]]),
#  tensor([[0.6277]]),
#  tensor([[0.6252]]),
#  tensor([[0.6112]]),
#  tensor([[0.0014]]),
#  tensor([[0.6222]]),
#  ...]

# %%
plt.figure(figsize=(10,10))



plt.hist(torch.tensor(preds).reshape(1,-1), histtype='step', density=True, bins=50, color='blue',label='pred')        
plt.hist(np.average(torch.tensor(preds)).reshape(1,-1), histtype='step', density=True, bins=50, color='black',label='pred')        


plt.hist((torch.tensor(f_weight_list)/torch.abs(torch.tensor(f_weight_list))).reshape(1,-1), histtype='step', density=True, bins=50, color='red',label='pred')        
plt.hist(np.average((torch.tensor(f_weight_list)/torch.abs(torch.tensor(f_weight_list))).reshape(1,-1)), histtype='step', density=True, bins=50, color='green',label='pred')        


plt.legend()
plt.xlim([-1.1,1.1])

plt.show()

# %%
torch.tensor(f_weight_list)
# Out:
# tensor([-0.0220, -0.0220, -0.0220,  ...,  0.0220,  0.0220,  0.0220])

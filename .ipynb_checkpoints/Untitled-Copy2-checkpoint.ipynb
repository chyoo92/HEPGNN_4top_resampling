# %%
import torch
import os
import numpy as np
import glob
import h5py
# from torch_geometric.nn import radius_graph
path1 = '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/*'
list_name = glob.glob(path1)
save_path = '/users/yewzzang/data_graph/h5/4top/ev1_v2_210520_0/'
# path2 = '/store/hep/users/yewzzang/4top_QCD_ttbar/data_graph/pt/*_weight_*/*'
# list_name2 = glob.glob(path2)

# list_name = list_name1 + list_name2

file_list_pt = [file for file in list_name if file.endswith(".pt")]

# %%
file_list_pt
# Out:
# ['/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-61.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-58.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-43.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-32.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-62.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-24.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-59.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-52.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-98.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-20.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-125.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-130.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-83.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-118.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-80.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-12.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-71.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-11.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-115.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-101.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-92.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-85.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-48.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-66.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-100.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-57.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-41.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-56.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-121.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-72.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-2.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-3.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-45.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-18.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-123.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-107.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-117.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-73.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-64.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-15.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-109.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-102.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-104.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-105.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-42.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-53.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-69.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-114.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-47.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-128.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-68.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-60.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-127.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-122.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-106.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-9.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-94.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-7.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-77.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-38.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-78.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-5.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-97.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-119.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-1.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-28.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-8.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-40.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-14.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-26.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-50.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-35.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-124.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-79.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-25.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-33.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-74.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-4.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-36.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-81.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-95.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-22.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-65.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-133.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-10.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-31.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-116.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-51.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-76.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-13.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-111.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-129.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-120.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-82.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-39.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-23.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-16.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-88.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-49.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-37.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-126.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-21.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-103.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-29.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-131.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-99.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-70.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-27.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-112.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-108.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-46.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-110.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-91.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-44.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-67.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-90.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-113.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-34.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-89.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-75.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-93.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-84.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-6.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-87.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-86.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-17.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-55.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-19.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-30.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-96.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-54.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-63.pt',
#  '/users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-132.pt']

# %%
for i in range(len(file_list_pt)):
    file_name = file_list_pt[i]
    print(file_name)
    
    edge_index_p = []
    pos_p = []
    x_p = []
    y_p = []
    file = torch.load(file_name)
    for j in range(len(file)):
        
        
        edge_index_p.append(file[j].edge_index)
        pos_p.append(file[j].pos)
        x_p.append(file[j].x)
        y_p.append(file[j].y)

    edge_flat = [[] for _ in range(len(y_p))]
    pos_flat = [[] for _ in range(len(y_p))]
    x_flat = [[] for _ in range(len(y_p))]

    y_flat = y_p
    for k in range(len(y_p)):
        
        edge_f = [y for x in edge_index_p[k] for y in x]
       
        pos_f = [y for x in pos_p[k] for y in x]
        x_f = [y for x in x_p[k] for y in x]

        
        edge_flat[k] = np.asarray(edge_f)

        pos_flat[k] = np.asarray(pos_f)
        x_flat[k] = np.asarray(x_f)

    test = file_name.split('/')[-1].split('.')[0]
    
    
    save_file = save_path + str(test)
    if not os.path.exists(save_path): os.makedirs(save_path)

    
    f = h5py.File(save_file +'.h5', mode='w')

    dt = h5py.special_dtype(vlen=np.dtype('float32'))
    g = f.create_group("group")
    
    pos = g.create_group("pos")
    x_fea = g.create_group("fea")
    edge_index = g.create_group("edge")
    label = g.create_group("label")
    
    pos.create_dataset('pos', (len(pos_flat),), dtype=dt)
    pos['pos'][...] = pos_flat
    x_fea.create_dataset('fea', (len(pos_flat),), dtype=dt)
    x_fea['fea'][...] = x_flat
    edge_index.create_dataset('edge', (len(pos_flat),), dtype=dt)
    edge_index['edge'][...] = edge_flat
    label.create_dataset('label', (len(pos_flat),), dtype=dt)
    label['label'][...] = y_flat
 
    f.close()
# Out:
# /users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-61.pt
# /users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-58.pt
# /users/yewzzang/data_graph/pt/4top_weight_210709/ex1_v2_210520_0/output_ex1_v2-powheg-43.pt

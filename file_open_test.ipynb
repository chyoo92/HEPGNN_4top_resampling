# %%
import h5py
import numpy as np

# %%
import torch
import sys, os

# %%
sys.path.append("./python")
from model.allModel import *

# %%
f = torch.load('/users/yewzzang/TTTT_TuneCP5_13TeV-amcatnlo-pythia8/4top_dump_ex2/220323_084833/h5/4top_ex2_delphes_3.pt')

# %%
f[0].x[0][-1]
# Out:
# tensor(0.0220)

# %%
for i in range(len(f)):
    print(f[i].x[0][-1])
# Out:
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# tensor(-0.0220)
# ...

# %%
len(f)
# Out:
# 10185

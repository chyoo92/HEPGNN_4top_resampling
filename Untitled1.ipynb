# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
real_4Q_all = [0.891,0.931,0.978]
real_tQ_all = [0.835,0.874,0.938]
real_4t_all = [0.799,0.829,0.863]

real_4Q_no = [0.881,0.914,0.977]
real_tQ_no = [0.808,0.852,0.926]
real_4t_no = [0.787,0.803,0.865]

resa_4Q_all = [0.904,0.935,0.981]
resa_tQ_all = [0.835,0.876,0.938]
resa_4t_all = [0.826,0.850,0.896]

resa_4Q_no = [0.891,0.925,0.979]
resa_tQ_no = [0.809,0.853,0.925]
resa_4t_no = [0.808,0.829,0.877]

# %%
plt.plot([3,4,5],real_4Q_all,'.r',label='4top vs QCD real alledge')
plt.plot([3,4,5],real_tQ_all,'.b',label='ttbar vs QCD real alledge')
plt.plot([3,4,5],real_4t_all,'.g',label='4top vs ttbar real alledge')
plt.plot([3,4,5],real_4Q_no,'*r',label='4top vs QCD real noedge')
plt.plot([3,4,5],real_tQ_no,'*b',label='ttbar vs QCD real noedge')
plt.plot([3,4,5],real_4t_no,'*g',label='4top vs ttbar real noedge')
plt.legend(bbox_to_anchor=(1, 1, 0, 0),fontsize=15)
plt.show()

# %%
plt.plot([3,4,5],resa_4Q_all,'.r',label='4top vs QCD resampling alledge')
plt.plot([3,4,5],resa_tQ_all,'.b',label='ttbar vs QCD resampling alledge')
plt.plot([3,4,5],resa_4t_all,'.g',label='4top vs ttbar resampling alledge')
plt.plot([3,4,5],resa_4Q_no,'*r',label='4top vs QCD resampling noedge')
plt.plot([3,4,5],resa_tQ_no,'*b',label='ttbar vs QCD resampling noedge')
plt.plot([3,4,5],resa_4t_no,'*g',label='4top vs ttbar resampling noedge')
plt.legend(bbox_to_anchor=(1, 1, 0, 0),fontsize=15)
plt.show()

# %%
plt.plot([3,4,5],real_4Q_no,'.r',label='4top vs QCD real noedge')
plt.plot([3,4,5],real_tQ_no,'.b',label='ttbar vs QCD real noedge')
plt.plot([3,4,5],real_4t_no,'.g',label='4top vs ttbar real noedge')

plt.plot([3,4,5],resa_4Q_no,'*r',label='4top vs QCD resampling noedge')
plt.plot([3,4,5],resa_tQ_no,'*b',label='ttbar vs QCD resampling noedge')
plt.plot([3,4,5],resa_4t_no,'*g',label='4top vs ttbar resampling noedge')
plt.legend(bbox_to_anchor=(1, 1, 0, 0),fontsize=15)
plt.show()

# %%
plt.plot([3,4,5],real_4Q_all,'.r',label='4top vs QCD real alledge')
plt.plot([3,4,5],real_tQ_all,'.b',label='ttbar vs QCD real alledge')
plt.plot([3,4,5],real_4t_all,'.g',label='4top vs ttbar real alledge')


plt.plot([3,4,5],resa_4Q_all,'*r',label='4top vs QCD resampling alledge')
plt.plot([3,4,5],resa_tQ_all,'*b',label='ttbar vs QCD resampling alledge')
plt.plot([3,4,5],resa_4t_all,'*g',label='4top vs ttbar resampling alledge')


plt.legend(bbox_to_anchor=(1, 1, 0, 0),fontsize=15)
plt.show()
